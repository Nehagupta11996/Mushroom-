# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Mushrooms.csv")

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df["class"].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %% [markdown]
# This is a classification problem

# %%
df["cap-shape"].value_counts()
# Out:
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64

# %%
df["cap-surface"].value_counts()
# Out:
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no null vales in the dataset

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["class"]=LE.fit_transform(df["class"])

# %%
df.head()
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      1         x           s         n       t    p               f
# 1      0         x           s         y       t    a               f
# 2      0         b           s         w       t    l               f
# 3      1         x           y         w       t    p               f
# 4      0         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df["cap-shape"]=LE.fit_transform(df["cap-shape"])

# %%
df["cap-surface"]=LE.fit_transform(df["cap-surface"])

# %%
df["cap-color"]=LE.fit_transform(df["cap-color"])

# %%
df["bruises"]=LE.fit_transform(df["bruises"])

# %%
df["odor"]=LE.fit_transform(df["odor"])

# %%
df["gill-attachment"]=LE.fit_transform(df["gill-attachment"])

# %%
df["gill-spacing"]=LE.fit_transform(df["gill-spacing"])

# %%
df["gill-size"]=LE.fit_transform(df["gill-size"])

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df["gill-color"]=LE.fit_transform(df["gill-color"])

# %%
df["stalk-shape"]=LE.fit_transform(df["stalk-shape"])

# %%
df["stalk-root"]=LE.fit_transform(df["stalk-root"])

# %%
df["stalk-surface-above-ring"]=LE.fit_transform(df["stalk-surface-above-ring"])

# %%
df["stalk-color-below-ring"]=LE.fit_transform(df["stalk-color-below-ring"])

# %%
df["veil-type"]=LE.fit_transform(df["veil-type"])

# %%
df["veil-color"]=LE.fit_transform(df["veil-color"])

# %%
df["ring-number"]=LE.fit_transform(df["ring-number"])

# %%
df["ring-type"]=LE.fit_transform(df["ring-type"])

# %%
df["spore-print-color"]=LE.fit_transform(df["spore-print-color"])

# %%
df["population"]=LE.fit_transform(df["population"])

# %%
df["habitat"]=LE.fit_transform(df["habitat"])

# %% [markdown]
# label encoding to transfer the data in to integer

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         s
# 1             0          0           4  ...                         s
# 2             0          0           5  ...                         s
# 3             0          1           5  ...                         s
# 4             1          0           4  ...                         s
#
#    stalk-color-above-ring  stalk-color-below-ring veil-type veil-color  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int32
#  1   cap-shape                 8124 non-null   int32
#  2   cap-surface               8124 non-null   int32
#  3   cap-color                 8124 non-null   int32
#  4   bruises                   8124 non-null   int32
#  5   odor                      8124 non-null   int32
#  6   gill-attachment           8124 non-null   int32
#  7   gill-spacing              8124 non-null   int32
#  8   gill-size                 8124 non-null   int32
#  9   gill-color                8124 non-null   int32
#  10  stalk-shape               8124 non-null   int32
#  11  stalk-root                8124 non-null   int32
#  12  stalk-surface-above-ring  8124 non-null   int32
#  13  stalk-surface-below-ring  8124 non-null   object
# ...

# %%
df["stalk-surface-below-ring"]=LE.fit_transform(df["stalk-surface-below-ring"])

# %%
df["stalk-color-above-ring"]=LE.fit_transform(df["stalk-color-above-ring"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int32
#  1   cap-shape                 8124 non-null   int32
#  2   cap-surface               8124 non-null   int32
#  3   cap-color                 8124 non-null   int32
#  4   bruises                   8124 non-null   int32
#  5   odor                      8124 non-null   int32
#  6   gill-attachment           8124 non-null   int32
#  7   gill-spacing              8124 non-null   int32
#  8   gill-size                 8124 non-null   int32
#  9   gill-color                8124 non-null   int32
#  10  stalk-shape               8124 non-null   int32
#  11  stalk-root                8124 non-null   int32
#  12  stalk-surface-above-ring  8124 non-null   int32
#  13  stalk-surface-below-ring  8124 non-null   int32
# ...

# %%
##from sklearn.preprocessing import LabelEncoder
#LE=LabelEncoder()

#collist=df.columns.values

#for i in range(0,len(collist)):
#    df[collist[i]]=LE.fit_transform(df[collist[i]])

# %% [markdown]
# converted the data into int
# doing individually will take time so by applying for loop it will take very less time

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaledX = scaler.fit_transform(df)

# %%
scaledX
# Out:
# array([[ 1.0366127 ,  1.02971224,  0.14012794, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [-0.96468045,  1.02971224,  0.14012794, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [-0.96468045, -2.08704716,  0.14012794, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [-0.96468045, -0.8403434 ,  0.14012794, ..., -1.50964337,
#         -2.11182722,  0.28570978],
#        [ 1.0366127 , -0.21699152,  0.95327039, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [-0.96468045,  1.02971224,  0.14012794, ...,  0.16925365,
#         -2.11182722,  0.28570978]])

# %% [markdown]
# standard scaler is done to make mean as 0 and standard deviation as 1
# this is the prerequisite of PCA the data should be scalled

# %%
from sklearn.decomposition import PCA

testpca=PCA()
Y=testpca.fit(scaledX)

# %%
Y.explained_variance_ratio_
# Out:
# array([1.90176569e-01, 1.25728104e-01, 1.15693658e-01, 9.94322019e-02,
#        8.04583336e-02, 6.46070210e-02, 4.46239634e-02, 4.37048093e-02,
#        3.52946410e-02, 3.24955264e-02, 2.65924341e-02, 2.49764992e-02,
#        2.31704565e-02, 2.20732934e-02, 1.77954237e-02, 1.60119695e-02,
#        1.00579949e-02, 9.03100835e-03, 6.46951497e-03, 5.64724272e-03,
#        3.31654518e-03, 2.64279023e-03, 3.77085401e-35])

# %%
var_cum = np.cumsum(Y.explained_variance_ratio_)*100

# %%
var_cum
# Out:
# array([ 19.01765686,  31.5904673 ,  43.15983308,  53.10305326,
#         61.14888662,  67.60958873,  72.07198507,  76.442466  ,
#         79.9719301 ,  83.22148274,  85.88072615,  88.37837607,
#         90.69542171,  92.90275106,  94.68229342,  96.28349037,
#         97.28928985,  98.19239069,  98.83934219,  99.40406646,
#         99.73572098, 100.        , 100.        ])

# %% [markdown]
# This gives the information of the data that by taking how many columns and how many rows we can get maximum information.

# %%
k=np.argmax(var_cum>95)
print("no of components explaining 94% variance:",k)
# Out:
# no of components explaining 94% variance: 15

# %%
FinalPCA=PCA(n_components=15)
FinalData = FinalPCA.fit_transform(scaledX)

# %%
FinalData2=pd.DataFrame(FinalData)
FinalData2
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.321351 -0.694031 -0.235421 -0.374467  2.079769 -1.564607  0.892720
# 1    -2.476977 -0.080202  0.803020 -0.138002  1.824881 -1.313558  1.021792
# 2    -2.179906 -0.770028  0.617134  0.559193  2.182259 -0.702609 -1.695972
# 3    -0.580738 -0.484832 -0.051059 -0.268147  2.804549 -2.034097  0.789095
# 4    -0.114274 -1.921547  3.273843  0.297390 -1.056278 -0.837058  0.219642
# ...        ...       ...       ...       ...       ...       ...       ...
# 8119 -2.525553  0.043004 -1.621419  6.881085 -2.129876 -1.820714  0.213691
# 8120 -2.702490  0.497329 -3.206229  8.334571 -3.300848 -2.783027  1.639199
# 8121 -1.891065  0.151836 -1.597775  6.942838 -1.917141 -1.952160 -0.351531
# 8122  3.729148 -1.121225 -0.719805 -0.109249  0.111862 -0.389792 -0.317034
# 8123 -1.940954 -0.397285 -1.730964  6.952300 -2.088274 -1.654208  1.342663
#
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %% [markdown]
# CREATED FINAL DATASET AND EXTRACTED 8 COLUMNS
# Now there are 15 columns

# %%
plt.axvline(x=k, color="k", linestyle="--")
plt.axhline(y=95,color="r",linestyle="--")

plt.plot(var_cum)
plt.show()

# %%
df.dtypes
# Out:
# class                       int32
# cap-shape                   int32
# cap-surface                 int32
# cap-color                   int32
# bruises                     int32
# odor                        int32
# gill-attachment             int32
# gill-spacing                int32
# gill-size                   int32
# gill-color                  int32
# stalk-shape                 int32
# stalk-root                  int32
# stalk-surface-above-ring    int32
# stalk-surface-below-ring    int32
# stalk-color-above-ring      int32
# stalk-color-below-ring      int32
# veil-type                   int32
# veil-color                  int32
# ring-number                 int32
# ring-type                   int32
# spore-print-color           int32
# population                  int32
# habitat                     int32
# dtype: object

# %% [markdown]
# The data type of all the columns are int datatype

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# No null values

# %%
sns.countplot(df["class"])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# Both the class are equally distributed, so there is no class imbalance issue exists

# %%
collist=df.columns.values
ncol=23
nrows=15


plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color="green",orient="v")
    plt.tight_layout()

# %% [markdown]
# There are outliers present in some columns

# %%
cor=df.corr()
cor
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %% [markdown]
# correlation between the columns

# %%
sns.heatmap(cor,annot=True,linewidths=1,linecolor="green")
# Out:
# <AxesSubplot:>

# %% [markdown]
# heatmap to show the correlation with values

# %%
df.skew()
# Out:
# class                       0.071946
# cap-shape                  -0.247052
# cap-surface                -0.590859
# cap-color                   0.706965
# bruises                     0.342750
# odor                       -0.080790
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                  0.061410
# stalk-shape                -0.271345
# stalk-root                  0.947852
# stalk-surface-above-ring   -1.098739
# stalk-surface-below-ring   -0.757703
# stalk-color-above-ring     -1.835434
# stalk-color-below-ring     -1.791593
# veil-type                   0.000000
# veil-color                 -6.946944
# ring-number                 2.701657
# ring-type                  -0.290018
# spore-print-color           0.548426
# population                 -1.413096
# habitat                     0.985548
# dtype: float64

# %% [markdown]
# skewness is there in many columns

# %%
x=df.drop("class",axis=1)
y=df["class"]

# %% [markdown]
# seprated the input and output data

# %%
from sklearn.preprocessing import power_transform 
df_new=power_transform(x)

df_new=pd.DataFrame(df_new,columns=x.columns)

# %% [markdown]
# removing outliers
#
# tried to remove outliers but getting error again and again and the ticket was raised for the same but not got the resolution so i decided to move forward with the same data

# %% [markdown]
# df_new.skew()

# %%
df.skew()
# Out:
# class                       0.071946
# cap-shape                  -0.247052
# cap-surface                -0.590859
# cap-color                   0.706965
# bruises                     0.342750
# odor                       -0.080790
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                  0.061410
# stalk-shape                -0.271345
# stalk-root                  0.947852
# stalk-surface-above-ring   -1.098739
# stalk-surface-below-ring   -0.757703
# stalk-color-above-ring     -1.835434
# stalk-color-below-ring     -1.791593
# veil-type                   0.000000
# veil-color                 -6.946944
# ring-number                 2.701657
# ring-type                  -0.290018
# spore-print-color           0.548426
# population                 -1.413096
# habitat                     0.985548
# dtype: float64

# %% [raw]
# Bulk data

# %% [markdown]
# from scipy.stats import zscore
#
# z=np.abs(zscore(df))
#
# new_df=df[(z<3).all(axis=1)]

# %% [markdown]
# new_df.shape

# %%
df.shape
# Out:
# (8124, 23)

# %%
df_new.shape
# Out:
# (8124, 22)

# %%
df_new.skew()
# Out:
# cap-shape                  -0.205860
# cap-surface                -0.473764
# cap-color                   0.004059
# bruises                     0.342750
# odor                       -0.144660
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                 -0.246738
# stalk-shape                -0.271345
# stalk-root                  0.023182
# stalk-surface-above-ring   -0.438332
# stalk-surface-below-ring   -0.114150
# stalk-color-above-ring     -0.964471
# stalk-color-below-ring     -0.925320
# veil-type                   0.000000
# veil-color                  5.797741
# ring-number                -0.499098
# ring-type                  -0.339232
# spore-print-color           0.018174
# population                 -0.368219
# habitat                     0.123132
# dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
for i in range(200):
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.33, random_state=i)
    from sklearn.tree import DecisionTreeClassifier
    lm=DecisionTreeClassifier()
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    accu=accuracy_score(y_test,pred)
    print(accu*100, "at random_state",i)
# Out:
# 100.0 at random_state 0
# 100.0 at random_state 1
# 100.0 at random_state 2
# 100.0 at random_state 3
# 100.0 at random_state 4
# 100.0 at random_state 5
# 100.0 at random_state 6
# 100.0 at random_state 7
# 100.0 at random_state 8
# 100.0 at random_state 9
# 100.0 at random_state 10
# 100.0 at random_state 11
# 100.0 at random_state 12
# 100.0 at random_state 13
# 100.0 at random_state 14
# 100.0 at random_state 15
# 100.0 at random_state 16
# 100.0 at random_state 17
# 100.0 at random_state 18
# 100.0 at random_state 19
# 100.0 at random_state 20
# 100.0 at random_state 21
# 100.0 at random_state 22
# 100.0 at random_state 23
# 100.0 at random_state 24
# 100.0 at random_state 25
# 100.0 at random_state 26
# 100.0 at random_state 27
# 100.0 at random_state 28
# 100.0 at random_state 29
# 100.0 at random_state 30
# 100.0 at random_state 31
# 100.0 at random_state 32
# 100.0 at random_state 33
# 100.0 at random_state 34
# 100.0 at random_state 35
# 100.0 at random_state 36
# ...

# %% [markdown]
# finding the best random state

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# %% [markdown]
# imported the packages required to find the best accuracy

# %%
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
preddtc=DTC.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1382
#            1       1.00      0.98      0.99      1299
#
#     accuracy                           0.99      2681
#    macro avg       0.99      0.99      0.99      2681
# weighted avg       0.99      0.99      0.99      2681

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
pred=RFC.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1382
#            1       1.00      1.00      1.00      1299
#
#     accuracy                           1.00      2681
#    macro avg       1.00      1.00      1.00      2681
# weighted avg       1.00      1.00      1.00      2681

# %%
SV=SVC()
SV.fit(x_train,y_train)
pred=SV.predict(x_test)
acc=classification_report(y_test,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1382
#            1       1.00      0.98      0.99      1299
#
#     accuracy                           0.99      2681
#    macro avg       0.99      0.99      0.99      2681
# weighted avg       0.99      0.99      0.99      2681

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(DTC,x,y,cv=5).mean())
print(cross_val_score(RFC,x,y,cv=5).mean())
print(cross_val_score(SV,x,y,cv=5).mean())
# Out:
# 0.9039611974232665
# 0.8947239105721865
# 0.841292231906025

# %%
df1=pd.DataFrame(preddtc)
df1.to_csv("mushroom_final.csv")

# %%
import joblib
joblib.dump(df1,"MushroomSubmission1.pkl")
# Out:
# ['MushroomSubmission1.pkl']

# %% [markdown]
# imported the data in object streaming form
